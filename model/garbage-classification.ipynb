# %% [markdown]
# # Garbage classification
# [Source]("https://www.kaggle.com/code/adenarayana/garbage-classification-pytorch"])

# %% [markdown]
# ## 0. Setup

# %%
# Imports
import torch
import torch.nn as nn
import torchvision
from torchvision import datasets
from torch.utils.data import DataLoader, random_split
from torchinfo import summary

# Input file preparation
from pathlib import Path
import random
import matplotlib.pyplot as plt

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cpu

# %%
# Image file path
image_path = Path(
    "./data/garbage-classification/Garbage classification/Garbage classification"
)

image_path
# Out:
# WindowsPath('data/garbage-classification/Garbage classification/Garbage classification')

# %%
# create a list of all image files
image_path_list = list(image_path.glob("*/*.jpg"))

# select a random image (directory)
random_image_path = random.choice(image_path_list)

# plot the selected image
img_random = plt.imread(random_image_path)
plt.imshow(img_random)
plt.title(random_image_path.parent.stem)  # title is the folder name
plt.axis("off")
plt.show()

# %% [markdown]
# ## 1. Data preprocessing

# %%
# get the trained model parameters
weights = torchvision.models.EfficientNet_B0_Weights.DEFAULT

# create data transformation based on the pretrained model
data_transform = weights.transforms()

print(data_transform)
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BICUBIC
# )

# %%
# create dataset using ImageFolder function from torchvision
img_dataset = datasets.ImageFolder(root=image_path, transform=data_transform)

print(img_dataset)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2527
#     Root location: data\garbage-classification\Garbage classification\Garbage classification
#     StandardTransform
# Transform: ImageClassification(
#                crop_size=[224]
#                resize_size=[256]
#                mean=[0.485, 0.456, 0.406]
#                std=[0.229, 0.224, 0.225]
#                interpolation=InterpolationMode.BICUBIC
#            )

# %%
# we can use the image dataset to create a list of class names (garbage type)
class_names = img_dataset.classes
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
# set the training and testing data size
train_size, test_size = 0.7, 0.3

# split the dataset into training anda testing dataset
train_data, test_data = random_split(img_dataset, [train_size, test_size])

len(train_data), len(test_data)
# Out:
# (1769, 758)

# %%
# training dataloader
train_dataloader = DataLoader(
    dataset=train_data, batch_size=32, num_workers=2, shuffle=True
)

# testing dataloader
test_dataloader = DataLoader(
    dataset=test_data, batch_size=32, num_workers=2, shuffle=False
)

print(len(train_dataloader))
print(len(test_dataloader))
# Out:
# 56
# 24

# %%
train_image_batch, train_label_batch = next(iter(train_dataloader))

train_image_batch.shape, train_label_batch.shape
# Out:
# (torch.Size([32, 3, 224, 224]), torch.Size([32]))

# %%
img_batch = train_image_batch[0, :, :, :]
img_batch_label = class_names[train_label_batch[0]]

plt.imshow(img_batch.permute(1, 2, 0))
plt.title(img_batch_label)
plt.axis("off")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4558606..1.923538].

# %% [markdown]
# ## 3. Model setup

# %%
# download the pretrained EfficientNet model
model = torchvision.models.efficientnet_b0(weights=weights).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to C:\Users\filip/.cache\torch\hub\checkpoints\efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 47.3MB/s]

# %%
summary(
    model=model,
    input_size=(32, 3, 224, 224),  # (batch_size, channels, height, width)
    col_names=["input_size", "output_size", "num_params", "trainable"],
    col_width=20,
    row_settings=["var_names"],
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [32, 3, 224, 224]    [32, 1000]           --                   True
# ├─Sequential (features)                                      [32, 3, 224, 224]    [32, 1280, 7, 7]     --                   True
# │    └─Conv2dNormActivation (0)                              [32, 3, 224, 224]    [32, 32, 112, 112]   --                   True
# │    │    └─Conv2d (0)                                       [32, 3, 224, 224]    [32, 32, 112, 112]   864                  True
# │    │    └─BatchNorm2d (1)                                  [32, 32, 112, 112]   [32, 32, 112, 112]   64                   True
# │    │    └─SiLU (2)                                         [32, 32, 112, 112]   [32, 32, 112, 112]   --                   --
# │    └─Sequential (1)                                        [32, 32, 112, 112]   [32, 16, 112, 112]   --                   True
# │    │    └─MBConv (0)                                       [32, 32, 112, 112]   [32, 16, 112, 112]   1,448                True
# │    └─Sequential (2)                                        [32, 16, 112, 112]   [32, 24, 56, 56]     --                   True
# │    │    └─MBConv (0)                                       [32, 16, 112, 112]   [32, 24, 56, 56]     6,004                True
# │    │    └─MBConv (1)                                       [32, 24, 56, 56]     [32, 24, 56, 56]     10,710               True
# │    └─Sequential (3)                                        [32, 24, 56, 56]     [32, 40, 28, 28]     --                   True
# │    │    └─MBConv (0)                                       [32, 24, 56, 56]     [32, 40, 28, 28]     15,350               True
# │    │    └─MBConv (1)                                       [32, 40, 28, 28]     [32, 40, 28, 28]     31,290               True
# │    └─Sequential (4)                                        [32, 40, 28, 28]     [32, 80, 14, 14]     --                   True
# │    │    └─MBConv (0)                                       [32, 40, 28, 28]     [32, 80, 14, 14]     37,130               True
# │    │    └─MBConv (1)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    │    └─MBConv (2)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    └─Sequential (5)                                        [32, 80, 14, 14]     [32, 112, 14, 14]    --                   True
# │    │    └─MBConv (0)                                       [32, 80, 14, 14]     [32, 112, 14, 14]    126,004              True
# │    │    └─MBConv (1)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    │    └─MBConv (2)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    └─Sequential (6)                                        [32, 112, 14, 14]    [32, 192, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 112, 14, 14]    [32, 192, 7, 7]      262,492              True
# │    │    └─MBConv (1)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (2)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (3)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    └─Sequential (7)                                        [32, 192, 7, 7]      [32, 320, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 192, 7, 7]      [32, 320, 7, 7]      717,232              True
# │    └─Conv2dNormActivation (8)                              [32, 320, 7, 7]      [32, 1280, 7, 7]     --                   True
# │    │    └─Conv2d (0)                                       [32, 320, 7, 7]      [32, 1280, 7, 7]     409,600              True
# │    │    └─BatchNorm2d (1)                                  [32, 1280, 7, 7]     [32, 1280, 7, 7]     2,560                True
# │    │    └─SiLU (2)                                         [32, 1280, 7, 7]     [32, 1280, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [32, 1280, 7, 7]     [32, 1280, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [32, 1280]           [32, 1000]           --                   True
# │    └─Dropout (0)                                           [32, 1280]           [32, 1280]           --                   --
# │    └─Linear (1)                                            [32, 1280]           [32, 1000]           1,281,000            True
# ============================================================================================================================================
# Total params: 5,288,548
# Trainable params: 5,288,548
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 12.35
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 3452.35
# Params size (MB): 21.15
# Estimated Total Size (MB): 3492.77
# ============================================================================================================================================

# %%
# first, freeze the model parameter in "features" layer
for param in model.features.parameters():
    param.requires_grad = False

# determine the output shape based on the total number of class
output_shape = len(class_names)

# redifine the "classifier" layer
model.classifier = nn.Sequential(
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(
        in_features=1280,
        out_features=output_shape,  # we only change this part
        bias=True,
    ),
).to(device)

# preview the model architecture after we modify the "classifier" layer
summary(
    model=model,
    input_size=(32, 3, 224, 224),
    col_names=["input_size", "output_size", "num_params", "trainable"],
    col_width=20,
    row_settings=["var_names"],
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [32, 3, 224, 224]    [32, 6]              --                   Partial
# ├─Sequential (features)                                      [32, 3, 224, 224]    [32, 1280, 7, 7]     --                   False
# │    └─Conv2dNormActivation (0)                              [32, 3, 224, 224]    [32, 32, 112, 112]   --                   False
# │    │    └─Conv2d (0)                                       [32, 3, 224, 224]    [32, 32, 112, 112]   (864)                False
# │    │    └─BatchNorm2d (1)                                  [32, 32, 112, 112]   [32, 32, 112, 112]   (64)                 False
# │    │    └─SiLU (2)                                         [32, 32, 112, 112]   [32, 32, 112, 112]   --                   --
# │    └─Sequential (1)                                        [32, 32, 112, 112]   [32, 16, 112, 112]   --                   False
# │    │    └─MBConv (0)                                       [32, 32, 112, 112]   [32, 16, 112, 112]   (1,448)              False
# │    └─Sequential (2)                                        [32, 16, 112, 112]   [32, 24, 56, 56]     --                   False
# │    │    └─MBConv (0)                                       [32, 16, 112, 112]   [32, 24, 56, 56]     (6,004)              False
# │    │    └─MBConv (1)                                       [32, 24, 56, 56]     [32, 24, 56, 56]     (10,710)             False
# │    └─Sequential (3)                                        [32, 24, 56, 56]     [32, 40, 28, 28]     --                   False
# │    │    └─MBConv (0)                                       [32, 24, 56, 56]     [32, 40, 28, 28]     (15,350)             False
# │    │    └─MBConv (1)                                       [32, 40, 28, 28]     [32, 40, 28, 28]     (31,290)             False
# │    └─Sequential (4)                                        [32, 40, 28, 28]     [32, 80, 14, 14]     --                   False
# │    │    └─MBConv (0)                                       [32, 40, 28, 28]     [32, 80, 14, 14]     (37,130)             False
# │    │    └─MBConv (1)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     (102,900)            False
# │    │    └─MBConv (2)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     (102,900)            False
# │    └─Sequential (5)                                        [32, 80, 14, 14]     [32, 112, 14, 14]    --                   False
# │    │    └─MBConv (0)                                       [32, 80, 14, 14]     [32, 112, 14, 14]    (126,004)            False
# │    │    └─MBConv (1)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    (208,572)            False
# │    │    └─MBConv (2)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    (208,572)            False
# │    └─Sequential (6)                                        [32, 112, 14, 14]    [32, 192, 7, 7]      --                   False
# │    │    └─MBConv (0)                                       [32, 112, 14, 14]    [32, 192, 7, 7]      (262,492)            False
# │    │    └─MBConv (1)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      (587,952)            False
# │    │    └─MBConv (2)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      (587,952)            False
# │    │    └─MBConv (3)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      (587,952)            False
# │    └─Sequential (7)                                        [32, 192, 7, 7]      [32, 320, 7, 7]      --                   False
# │    │    └─MBConv (0)                                       [32, 192, 7, 7]      [32, 320, 7, 7]      (717,232)            False
# │    └─Conv2dNormActivation (8)                              [32, 320, 7, 7]      [32, 1280, 7, 7]     --                   False
# │    │    └─Conv2d (0)                                       [32, 320, 7, 7]      [32, 1280, 7, 7]     (409,600)            False
# │    │    └─BatchNorm2d (1)                                  [32, 1280, 7, 7]     [32, 1280, 7, 7]     (2,560)              False
# │    │    └─SiLU (2)                                         [32, 1280, 7, 7]     [32, 1280, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [32, 1280, 7, 7]     [32, 1280, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [32, 1280]           [32, 6]              --                   True
# │    └─Dropout (0)                                           [32, 1280]           [32, 1280]           --                   --
# │    └─Linear (1)                                            [32, 1280]           [32, 6]              7,686                True
# ============================================================================================================================================
# Total params: 4,015,234
# Trainable params: 7,686
# Non-trainable params: 4,007,548
# Total mult-adds (Units.GIGABYTES): 12.31
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 3452.09
# Params size (MB): 16.06
# Estimated Total Size (MB): 3487.42
# ============================================================================================================================================

# %% [markdown]
# ## 4. Model training

# %%
loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 20 # optimal for the test loss

train_loss_holder = []
test_loss_holder = []

for epoch in range(epochs):
    print(f"Epoch: {epoch}\n------------------")

    train_loss = 0

    for X, y in train_dataloader:
        X, y = X.to(device), y.to(device)

        model.train()

        y_pred = model(X)

        loss = loss_fn(y_pred, y)
        train_loss += loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    train_loss /= len(train_dataloader)

    with torch.inference_mode():
        test_loss = 0

        for X, y in test_dataloader:
            X, y = X.to(device), y.to(device)

            model.eval()

            test_pred = model(X)

            test_loss += loss_fn(test_pred, y)

        test_loss /= len(test_dataloader)

    print(f"Train loss: {train_loss:.5f} | Test loss: {test_loss:.5f}\n")
    train_loss_holder.append(train_loss.detach().cpu().numpy())
    test_loss_holder.append(test_loss.detach().cpu().numpy())
# Out:
# Epoch: 0
# ------------------
# Train loss: 1.27390 | Test loss: 0.93139
#
# Epoch: 1
# ------------------
# Train loss: 0.83744 | Test loss: 0.73095
#
# Epoch: 2
# ------------------
# Train loss: 0.71312 | Test loss: 0.65082
#
# Epoch: 3
# ------------------
# Train loss: 0.62427 | Test loss: 0.61179
#
# Epoch: 4
# ------------------
# Train loss: 0.57654 | Test loss: 0.57536
#
# Epoch: 5
# ------------------
# Train loss: 0.53494 | Test loss: 0.54702
#
# Epoch: 6
# ------------------
# Train loss: 0.50848 | Test loss: 0.54332
#
# Epoch: 7
# ------------------
# Train loss: 0.47263 | Test loss: 0.52551
#
# Epoch: 8
# ------------------
# Train loss: 0.45545 | Test loss: 0.53170
#
# Epoch: 9
# ------------------
# Train loss: 0.45042 | Test loss: 0.51136
#
# Epoch: 10
# ------------------
# Train loss: 0.42294 | Test loss: 0.50785
#
# Epoch: 11
# ------------------
# Train loss: 0.39638 | Test loss: 0.49199
#
# Epoch: 12
# ------------------
# Train loss: 0.41023 | Test loss: 0.51042
#
# Epoch: 13
# ------------------
# Train loss: 0.38722 | Test loss: 0.50127
#
# Epoch: 14
# ------------------
# Train loss: 0.38614 | Test loss: 0.48740
#
# Epoch: 15
# ------------------
# Train loss: 0.37473 | Test loss: 0.47825
#
# Epoch: 16
# ------------------
# Train loss: 0.38180 | Test loss: 0.48860
#
# Epoch: 17
# ------------------
# Train loss: 0.36512 | Test loss: 0.47500
#
# Epoch: 18
# ------------------
# Train loss: 0.36672 | Test loss: 0.46682
#
# Epoch: 19
# ------------------
# Train loss: 0.33975 | Test loss: 0.46776
#
# Epoch: 20
# ------------------
# Train loss: 0.32757 | Test loss: 0.46547
#
# Epoch: 21
# ------------------
# Train loss: 0.34187 | Test loss: 0.45762
#
# Epoch: 22
# ------------------
# Train loss: 0.30851 | Test loss: 0.45938
#
# Epoch: 23
# ------------------
# Train loss: 0.34448 | Test loss: 0.46425
#
# Epoch: 24
# ------------------
# Train loss: 0.31934 | Test loss: 0.46590
#
# Epoch: 25
# ------------------
# Train loss: 0.31014 | Test loss: 0.47267
#
# Epoch: 26
# ------------------
# Train loss: 0.30481 | Test loss: 0.47823
#
# Epoch: 27
# ------------------
# Train loss: 0.31597 | Test loss: 0.45346
#
# Epoch: 28
# ------------------
# Train loss: 0.29706 | Test loss: 0.45066
#
# Epoch: 29
# ------------------
# Train loss: 0.29357 | Test loss: 0.44861
#
# Epoch: 30
# ------------------
# Train loss: 0.28940 | Test loss: 0.44933
#
# Epoch: 31
# ------------------
# Train loss: 0.27653 | Test loss: 0.45843
#
# Epoch: 32
# ------------------
# Train loss: 0.28828 | Test loss: 0.46397
#
# Epoch: 33
# ------------------
# Train loss: 0.26414 | Test loss: 0.46830
#
# Epoch: 34
# ------------------
# Train loss: 0.26911 | Test loss: 0.45322
#
# Epoch: 35
# ------------------
# Train loss: 0.28269 | Test loss: 0.46874
#
# Epoch: 36
# ------------------
# Train loss: 0.28225 | Test loss: 0.45712
#
# Epoch: 37
# ------------------
# Train loss: 0.28493 | Test loss: 0.45894
#
# Epoch: 38
# ------------------
# Train loss: 0.29112 | Test loss: 0.45922
#
# Epoch: 39
# ------------------
# Train loss: 0.27613 | Test loss: 0.46008
#
# Epoch: 40
# ------------------
# Train loss: 0.27706 | Test loss: 0.45222
#
# Epoch: 41
# ------------------
# Train loss: 0.26998 | Test loss: 0.45937
#
# Epoch: 42
# ------------------
# Train loss: 0.25015 | Test loss: 0.45136
#
# Epoch: 43
# ------------------
# Train loss: 0.25858 | Test loss: 0.45675
#
# Epoch: 44
# ------------------
# Train loss: 0.25858 | Test loss: 0.44537
#
# Epoch: 45
# ------------------
# Train loss: 0.24855 | Test loss: 0.44557
#
# Epoch: 46
# ------------------
# Train loss: 0.26764 | Test loss: 0.44214
#
# Epoch: 47
# ------------------
# Train loss: 0.24629 | Test loss: 0.46224
#
# Epoch: 48
# ------------------
# Train loss: 0.27922 | Test loss: 0.46265
#
# Epoch: 49
# ------------------
# Train loss: 0.25123 | Test loss: 0.44653

# %%
epoch_total = range(epochs)
fig, ax = plt.subplots()
ax.plot(epoch_total, train_loss_holder, "-o", label="Training loss")
ax.plot(epoch_total, test_loss_holder, "-*", label="Testing loss")
ax.grid(ls='--')
ax.set_xlabel("Epochs")
ax.set_ylabel("Loss")
ax.legend(edgecolor="black")
plt.show()

# %%
# Saving the trained model
torch.save(model.state_dict(), "garbage_classification_model.pth")
